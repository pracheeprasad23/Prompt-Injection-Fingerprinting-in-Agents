# %%
# !pip install -q bitsandbytes accelerate datasets tqdm

# %%
# For First Run

# !python /kaggle/input/datasets/vkymule/neuralchemy-cleaned/augment_neuralchemy_dataset.py \
    --input /kaggle/input/datasets/vkymule/neuralchemy-cleaned/cleaned_neuralchemy_dataset.jsonl

# %%
# # Session 2 and After: Resume from checkpoint


# !pip install -q bitsandbytes accelerate datasets tqdm
# # Copy checkpoint to working directory (Kaggle input is read-only)
# !cp /kaggle/input/datasets/vkymule/neuralchemy-cleaned/augmented_neuralchemy_dataset.jsonl /kaggle/working/
# # Resume — script auto-detects how many rows are already in the checkpoint
# !python /kaggle/input/datasets/vkymule/neuralchemy-cleaned/augment_neuralchemy_dataset.py \
#     --input /kaggle/input/datasets/vkymule/neuralchemy-cleaned/cleaned_neuralchemy_dataset.jsonl
